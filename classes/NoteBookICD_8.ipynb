# %% [markdown]
# # Notebook ICD - 8

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/andylmao/anaconda3/lib/python3.12/site-packages (1.5.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 7.6 MB/s eta 0:00:007.9 MB/s eta 0:00:01
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.1
#     Uninstalling scikit-learn-1.5.1:
#       Successfully uninstalled scikit-learn-1.5.1
# Successfully installed scikit-learn-1.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.5.2)
# Requirement already satisfied: numba>=0.51.2 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from umap-learn) (0.59.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /home/andylmao/anaconda3/lib/python3.12/site-packages (from umap-learn) (4.66.4)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from numba>=0.51.2->umap-learn) (0.42.0)
# Requirement already satisfied: joblib>=0.11 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/andylmao/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Datos

# %%
df = pd.read_csv("sign_mnist_train.csv")
print(df.head())
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
print(df.shape)
# Out:
# (27455, 785)

# %%
letter2encode = {'A': 0,'B': 1,'C': 2,'D': 3,'E': 4,'F': 5,'G': 6,'H': 7,'I': 8,'K': 10,'L': 11,'M': 12,
                'N': 13,'O': 14,'P': 15,'Q': 16,'R': 17,'S': 18,'T': 19,'U': 20,'V': 21,'W': 22,'X': 23, 'Y': 24}

def encode(character):
    return letter2encode[character]

# %%
WORD = 'AEIOU'
word = np.array(list(WORD))
embedded_word = list(map(encode, word))
print(embedded_word)
# Out:
# [0, 4, 8, 14, 20]

# %%
reduced_df = df[df['label'].isin(embedded_word)]
print(reduced_df.shape)
# Out:
# (5602, 785)

# %%
X = reduced_df.loc[:, reduced_df.columns != 'label'].values
print(len(X))
# Out:
# 5602

# %%
y = reduced_df['label'].values
print(len(y))
# Out:
# 5602

# %%
#print(X)
print(y)
# Out:
# [ 8 20 20 ...  0 14 20]

# %%
index = 0
for i in embedded_word:
    find = np.where(y == embedded_word[index])
    plt.imshow(X[find[0][0]].reshape(28,28))
    plt.show()
    index+=1

# %% [markdown]
# ## Librerias De tecnicas DR

# %%
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.manifold import TSNE
from umap import UMAP

# %% [markdown]
# # PCA

# %%
X_PCA = PCA(n_components=2).fit_transform(X)

scatter = plt.scatter(X_PCA[:,0], X_PCA[:,1], c=y)
plt.title('PCA plot in 2D')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*scatter.legend_elements())
plt.show()

# %% [markdown]
# # LDA

# %%
X_LDA = LDA(n_components=2).fit_transform(X,y)

scatter = plt.scatter(X_LDA[:,0], X_LDA[:,1], c=y)
plt.title('LDA plot in 2D')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*scatter.legend_elements())
plt.show()

# %% [markdown]
# # t-SNE

# %%
X_TSNE = TSNE(n_components=2).fit_transform(X)

scatter = plt.scatter(X_TSNE[:,0], X_TSNE[:,1], c=y)
plt.title('t-SNE plot in 2D')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*scatter.legend_elements())
plt.show()

# %% [markdown]
# # UMAP

# %%
X_UMAP = UMAP(n_components=2).fit_transform(X)

scatter = plt.scatter(X_UMAP[:,0], X_UMAP[:,1], c=y)
plt.title('UMAP plot in 2D')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*scatter.legend_elements())
plt.show()
# Out:
# /home/andylmao/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
